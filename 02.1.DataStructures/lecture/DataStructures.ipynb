# %% [markdown]
# <center>
#     <img src="https://upload.wikimedia.org/wikipedia/commons/a/a8/%D0%9B%D0%9E%D0%93%D0%9E_%D0%A8%D0%90%D0%94.png" width=500px/>
#     <br/>
#     <font>Python 2025</font><br/>
#     <br/>
#     <b style="font-size: 2em">Cтруктуры данных</b><br/>
#     <br/>
#     <font> Владислав Вихров, по материалам Иларии Беловой и Ярослава Золотарёва  $\heartsuit$</font><br/>
# </center>

# %% [markdown]
# ### План лекции

# %% [markdown]
# **Первая часть: (~1h)**
# 1. Устройство базовых типов данных: int, bool, float, str
#
# **Вторая часть: (~1.5h)**
# 1. Устройство контейнеров: tuple, list, set, frozenset, dict
# 2. Shallow\deep copy; packing\unpacking
#
# **Третья часть: (~0.5h)**
# 1. Comprehensions
# 2. Collections: defaultdict, deque, OrderedDict, Counter,
# 3. heapq

# %% [markdown]
# ### Определения → Объекты, ссылки, типы, значения, операции

# %%
# All data in a Python program is represented by objects or by relations between objects

a = 1       # `имя` = `значение`. Имени `a` присваивается ссылка на объект со значением 1
A = id(a)   # `id`. Ссылка, где лежит объект в памяти
t = type(a) # `тип`. Какими свойствами обладает
a, A, t

# %%
# Операция над объектами
b = 1
c = 2
a = b + c
a

# %% [markdown]
# ### "Магия" Python

# %% [markdown]
# #### Пример 1

# %%
list_of_immutables = list(range(5))
print(list_of_immutables)

# %%
for elem in list_of_immutables:
    elem = elem + 1
    # do something else
    print(elem, end=' ')
print()
    
print(list_of_immutables)

# %% [markdown]
# #### Пример 2

# %%
list_of_mutables = [[1], [1], [1]]
print(list_of_mutables)

ref_list_of_mutables = [[1]] * 3
print(ref_list_of_mutables)

# %%
for idx, elem in enumerate(list_of_mutables):
    elem.append(idx)
    
print(list_of_mutables)

# %%
for idx, elem in enumerate(ref_list_of_mutables):
    elem.append(idx)
    
print(ref_list_of_mutables)

# %% [markdown]
# ### Определения → Мутабельность/иммутабельность объектов

# %%
# Иммутабельные - не меняют значение по ссылке
# Примеры: int, float, str, tuple, frozenset
a = 1
b = a
a += 2
a, b

# %%
# Мутабельные - меняют значение по ссылке
# Примеры: list, set, dict
a = [1]
b = a
a += [2]
a, b

# %% [markdown]
# ### Ⅰ. Устройство базовых типов данных → int (1/8)

# %%
a = 322     
A = id(a)   
t = type(a)
a, A, t

# %%
a = 322
b = 322
a == b, id(a) == id(b)

# %% [markdown]
# ### Ⅰ. Устройство базовых типов данных → int  (2/8)

# %%
a = 322
A = id(a)
a = 323
id(a) == A

# %% [markdown]
# ### Ⅰ. Устройство базовых типов данных → int  (3/8)

# %%
a = 322
b = a
a == b, id(a) == id(b)  # В чём разница со случаем 1?

# %% [markdown]
# ### Ⅰ. Устройство базовых типов данных → int  (4/8)

# %%
a = 322
b = a
b = b + 1

id(a) == id(b)

# %%
a = 322
b = a
b += 1

id(a) == id(b)

# %% [markdown]
# ### Ⅰ. Устройство базовых типов данных → int (5/8)

# %%
# Немножко оптимизации: малые значения инта
a = 1
b = 1
print(id(a) == id(b), a is b)

a = 256
b = 256
print(id(a) == id(b), a is b)

a = 257
b = 257
print(id(a) == id(b), a is b)

# %%
# Немножко оптимизации: константы
a = 257
b = 257
print(id(a) == id(b))

def f():
    a = 257
    b = 257
    print(id(a) == id(b))
f()

# %% [markdown]
# ### Ⅰ. Устройство базовых типов данных → int (6/8)

# %%
# id можно вызвать и от типа
a = 322
b = 322
id(type(a)) == id(type(b))

# %%
# При желании можно переприсвоить и int
int = 1
print(id(1) == id(int), id(1) == id(type(1)))
import builtins; int = builtins.int

# %%
int = 1337
print(id(1337) == id(int), id(1337) == id(type(1337)))
import builtins; int = builtins.int

# %% [markdown]
# ###  Ⅰ. Устройство базовых типов данных → int (7/8)

# %%
# Сколько занимает int памяти?
import sys
a = 1
sys.getsizeof(a) #, sys.int_info

# %%
# А такой?
a = (1 << 30) - 1
sys.getsizeof(a)

# %%
# А такой?
a = (1 << 30)
sys.getsizeof(a)

# %%
# А такой?
a = (1 << 30) * (1 << 30)
sys.getsizeof(a)

# %%
# INT БЕСКОНЕЧНЫЙ

# %% [markdown]
# <b>Ⅰ. Устройство базовых типов данных → int (8/8)</b>
# <table>
# <tr>
# <td> Счетчик ссылок </td> <td>8 байт</td> <td> Q - unsigned long long</td>
# <tr/>
# <tr>
# <td> Ссылка на тип </td> <td>8 байт</td> <td> Q - unsigned long long </td>
# </tr>
# <tr>
# <td>Знак числа + его размер по основанию 2<sup>30</sup></td> <td>8 байт</td> <td> q - signed long long </td>
# </tr>
# <tr>
# <td> Каждый кусочек инта </td> <td>4 байта</td> <td> i - int </td>
# </tr>
# </table>

# %%
# Какой размер у a?
import sys
a = 437976919 + 87719511 * 2**30 + 107 * (2**30) ** 2
sys.getsizeof(a)

# %%
# Немного глянем во внутренности питона

import ctypes  # Библиотека, позволяющая работать напрямую с памятью
import struct  # Библиотека, связывающая питоновские объекты с их репрезентацией в памяти

print(struct.unpack("QQqiii", ctypes.string_at(id(a), 36)))
# a = 437976919 + 87719511 * 2**30 + 107 * (2**30) ** 2

# %%
# Поменять каждую из цифр разложения числа a
a = 437976919 + 87719511 * 2**30 + 107 * (2**30) ** 2

print(struct.unpack("QQqiii", ctypes.string_at(id(a), 36)))

# %% [markdown]
# ### Ⅰ. Устройство базовых типов данных → bool (1/2)

# %%
a = True
b = True
a == b, id(a) == id(b)

# %%
a = True
b = a
a &= False
a, b, a == b, id(a) == id(b)

# %% [markdown]
# ### Ⅰ. Устройство базовых типов данных → bool (2/2)
#
# <table>
# <tr>
# <td> Счетчик ссылок </td> <td>8 байт</td> <td> Q - unsigned long long </td>
# <tr/>
# <tr>
# <td> Ссылка на тип </td> <td>8 байт</td> <td> Q - unsigned long long </td>
# </tr>
# <tr>
# <td>0 или 1</td> <td>8 байт</td> <td> Q - unsigned long long</td>
# </tr>
# <tr>
# <td> Значение bool </td> <td>4 байта</td> <td> i - int </td>
# </tr>
# </table>

# %%
# Какой размер у a?
import sys
a = True
sys.getsizeof(a)

# %%
# Немного глянем inside
import ctypes
import struct

struct.unpack("LLli", ctypes.string_at(id(a), 28))

# %% [markdown]
# ### Ⅰ. Устройство базовых типов данных → float (1/7)

# %%
a = 1.1
b = 1.1
id(a) == id(b)

# %%
a = 1.1
b = a
id(a) == id(b)

# %% [markdown]
# ### Ⅰ. Устройство базовых типов данных → float (2/7)

# %%
a = 1.1
b = a
b = b + 1.45

a == b, id(a) == id(b)

# %%
a = 1.1
b = a
b += 1.45

a == b, id(a) == id(b)

# %% [markdown]
# ### Ⅰ. Устройство базовых типов данных → float (3/7)

# %%
# А что в случае типов?
a = 1.45
b = 1.47
id(type(a)) == id(type(b))

# %% [markdown]
# ### Ⅰ. Устройство базовых типов данных → float (4/7)

# %%
# Потеря точности
float(10**16 - 1) == 10**16

# %%
a = 1.7976931348623157e+308 + 228
b = 1.7976931348623157e+308 + 777777
a == b, id(a) == id(b)

# %% [markdown]
# ### Ⅰ. Устройство базовых типов данных → float (5/7)

# %%
a = 1.7976931348623157e+308; b = 10 ** 292  # 10.
print(a)
print(b) 
print(a+b)

# %%
1.7976931348623157e+308 * 2 == float('inf')

# %%
a = float('inf')
b = float('inf')
a == b, id(a) == id(b)

# %%
a = float('nan')
b = float('nan')
a == b, id(a) == id(b)

# %% [markdown]
# ### Ⅰ. Устройство базовых типов данных → float (6/7)

# %%
import sys
sys.getsizeof(1), sys.getsizeof(1.0)

# %%
sys.getsizeof(sys.float_info.max)

# %%
sys.getsizeof(float('inf'))

# %% [markdown]
# <b>Ⅰ. Устройство базовых типов данных → float (7/7)</b>
# <table>
# <tr>
# <td> Счетчик ссылок </td> <td>8 байт</td> <td> Q - unsigned long long </td>
# <tr/>
# <tr>
# <td> Ссылка на тип </td> <td>8 байт</td> <td> Q - unsigned long long </td>
# </tr>
# <tr>
# <td> double со значением </td> <td>8 байт</td> <td> d - double </td>
# </tr>
# </table>

# %%
# Какой размер у a?
import sys
a = 1.45
sys.getsizeof(a)

# %%
# Немного глянем inside
import ctypes
import struct

struct.unpack("LLd", ctypes.string_at(id(a), 24))

# %%
# Playground

# %% [markdown]
# ### Ⅰ. Устройство базовых типов данных → str (1/6)

# %%
a = "hello+world"
b = "hello+world"
a == b, id(a) == id(b)

# %% [markdown]
# ### Ⅰ. Устройство базовых типов данных → str (2/6)

# %%
a = "hello"
b = a
b = b + " world"

a == b, id(a) == id(b)

# %%
a = "hello"
b = a
b += " world"

a == b, id(a) == id(b)

# %% [markdown]
# ### Ⅰ. Устройство базовых типов данных → str (3/6)

# %%
# А что в случае типов?

a = "hello"
b = "world"
id(type(a)) == id(type(b))

# %% [markdown]
# ### Ⅰ. Устройство базовых типов данных → str (4/6)

# %%
# Немного оптимизации: интернирование

a = "helloworld"
b = "helloworld"
id(a) == id(b)

# %%
a = "a" * 100500
b = "a" * 100500
id(a) == id(b)

# %%
# Интернирование
import sys
a = sys.intern("a" * 100500)
b = sys.intern("a" * 100500)
id(a) == id(b)

# %% [markdown]
# <b> Ⅰ. Устройство базовых типов данных → str (5/6) </b>
# <table>
# <tr>
# <td> Счетчик ссылок </td> <td>8 байт</td> <td> Q - unsigned long long</td>
# <tr/>
# <tr>
# <td> Ссылка на тип </td> <td>8 байт</td> <td> Q - unsigned long long</td>
# </tr>
# <tr>
# <td> Число символов </td> <td>8 байт</td> <td> Q - unsigned long long</td>
# </tr>
# <tr>
# <td> Хэш </td> <td>8 байт</td> <td> q - signed long long </td>
# </tr>
# <tr>
# <td> Флаги, включая интернирование; служебная информация </td> <td>16 байт</td> <td> s - char[] </td>
# </tr>
# <tr>
# <td> Байты строки, заканчивающейся на \00 </td> <td> >= 1 байт </td> <td> s - char[] <td>
# </tr>
# </table>

# %%
# Какой размер у a?
import sys
a = "shad2025"
sys.getsizeof(a)

# %%
# Немного глянем inside

import ctypes
import struct

struct.unpack("3Qq16s8s", ctypes.string_at(id(a), 56))

# %%
# Playground

# %% [markdown]
# ### Ⅰ. Устройство базовых типов данных → str (6/6)

# %% [markdown]
# 1. Вставка буквы в начало/середину/конец строки?
# 2. Взятие длины от строки?
# 3. Поиск буквы в строке?
# 4. Поиск подстроки в строке?
# 5. Удаление буквы из строки?
# 6. Добавление строки к строке?

# %% [markdown]
# ### Ⅱ. Устройство контейнеров → list (1/10)

# %%
a = [1]
b = [1]
a == b, id(a) == id(b)

# %% [markdown]
# ### Ⅱ. Устройство контейнеров → list (2/10)

# %%
def printy(label, value):
    print(f"{label} == {value} -> {id(value)}")
    if not isinstance(value, int):
        for i, el in enumerate(value):
            print(f"{label}[{i}] == {el} -> {id(el)}")

a = 2; b = 4; my_list = [2, 4]

printy("a", a)
printy("b", b)
printy("my_list", my_list)

# %%
my_list[1] = 3

printy("a", a)
printy("b", b)
printy("my_list", my_list)

# %% [markdown]
# ### Ⅱ. Устройство контейнеров → list (3/10)

# %%
a = [1]
b = a
b = b + [2]

a, b, id(a) == id(b)

# %%
a = [1]
b = a
b += [2]

a, b, id(a) == id(b)

# %% [markdown]
# ### Ⅱ. Устройство контейнеров → list (4/10)

# %%
a = [1]
b = a
b.append(2)  # returns None

a, b, id(a) == id(b)

# %%
a = [1]
b = a
b.extend([2])

a, b, id(a) == id(b)

# %% [markdown]
# ### Ⅱ. Устройство контейнеров → list (5/10)

# %%
a = [1, 2]
b = a
b = b[:1]
a[0] = 5

a, b, id(a) == id(b)

# %%
a = [1, 2]
b = a
b[:1] = b[1:]

a, b, id(a) == id(b)

# %% [markdown]
# ### Ⅱ. Устройство контейнеров → list (6/10)

# %%
# А что в случае типов?
a = [1]
b = [2]
id(type(a)) == id(type(b))

# %% [markdown]
# ### Ⅱ. Устройство контейнеров → list (7/10)

# %%
# А что в случае пустых списков?
a = []
b = []
id(a) == id(b)

# %%
# А что в случае самозацикливания?
a = []
a.append(a)

printy('a', a)

# %% [markdown]
# ### Ⅱ. Устройство контейнеров → list (8/10)

# %%
# Сколько памяти ест список?
import sys
[].__sizeof__()

# %%
# Верно ли?
[1, 2, []].__sizeof__() == [1, 2, [1, 1, 1, 1]].__sizeof__()

# %% [markdown]
# <b>Ⅱ. Устройство контейнеров → list (9/10)</b>
# <table>
# <tr>
# <td> Счетчик ссылок </td> <td>8 байт</td> <td> Q - unsigned long long</td>
# <tr/>
# <tr>
# <td> Ссылка на тип </td> <td>8 байт</td> <td> Q - unsigned long long</td>
# </tr>
# <tr>
# <td> Длина списка </td> <td>8 байт</td> <td> Q - unsigned long long</td>
# </tr>
# <tr>
#     <td> Ссылка на данные
#     </td>
#     <td>
#         8 байт
#     </td> <td> Q - unsigned long long</td>
# </tr>
# <tr>
#     <td> Каждый кусочек данных
#     </td>
#     <td>
#         8 байт
#     </td> <td> Q - unsigned long long</td>
# </tr>
# <tr>
# <td> Длина списка с учетом аллокации </td> <td>8 байт</td>  <td> Q - unsigned long long</td>
# </tr>
# </table>

# %%
# Какой размер у a?
import sys
a = [1, 3, "ab"]  # can modify length, but a[0] must be int
a.__sizeof__()

# %%
# Немного глянем inside
import ctypes
import struct

data_1 = struct.unpack("5Q", ctypes.string_at(id(a), 40))
data_2 = struct.unpack(f"{len(a)}Q", ctypes.string_at(data_1[3], len(a) * 8))
data_3 = struct.unpack("3Qi", ctypes.string_at(data_2[0], 28))  # 0 -> 1
data_1, data_2, data_3

# %%
# Playground: modification

# %% [markdown]
# ### Ⅱ. Устройство контейнеров → list (10/10)

# %% [markdown]
# * Обновление по индексу в списке?
# * Вставка в список?
# * Удаление из списка?
# * Добавление в конец списка?
# * Сложить два списка?
# * Взять длину от списка?
# * Поиск в списке?

# %% [markdown]
# ### Ⅱ. Устройство контейнеров → tuple (1/9)

# %%
a = 1; c = 2; my_tuple = (1, 2)

printy("a", a)
printy("c", c)
printy("my_tuple", my_tuple)

# %% [markdown]
# ### Ⅱ. Устройство контейнеров → tuple (2/9)

# %%
a = (1,)
b = a
b = b + a

a, b, id(a) == id(b)

# %%
a = (1,)
b = a
b += a

a, b, id(a) == id(b)

# %% [markdown]
# ### Ⅱ. Устройство контейнеров → tuple (3/9)

# %%
# Что будет тут?

my_tuple = (1, 2, [])
printy("my_tuple", my_tuple)

my_tuple[2].append(2)

print(f"========= UPDATE =========")
printy("my_tuple", my_tuple)

# %% [markdown]
# ### Ⅱ. Устройство контейнеров → tuple (4/9)

# %%
# А что в случае типов?
a = (1,)
b = (2,)
id(type(a)) == id(type(b))

# %% [markdown]
# ### Ⅱ. Устройство контейнеров → tuple (5/9)

# %%
# Немножко оптимизации
a = ()
b = ()
id(a) == id(b)

# %%
a = (1, )
b = (1, )

id(a) == id(b)

# %% [markdown]
# ### Ⅱ. Устройство контейнеров → tuple (6/9)

# %%
# Где больше?
().__sizeof__(), [].__sizeof__()

# %%
# Верно ли?
(1, 2, 1, [1]).__sizeof__() == (1, 2, 1, 1).__sizeof__()

# %% [markdown]
# <b> Ⅱ. Устройство контейнеров → tuple (7/9)</b>
# <table>
# <tr>
# <td> Счетчик ссылок </td> <td>8 байт</td> <td> Q - unsigned long long</td>
# <tr/>
# <tr>
# <td> Ссылка на тип </td> <td>8 байт</td> <td> Q - unsigned long long</td>
# </tr>
# <tr>
# <td> Длина tuple </td> <td>8 байт</td> <td> Q - unsigned long long</td>
# </tr>
# <tr>
# <td> Ссылка на каждый элемент </td> <td> по 8 байт</td> <td> Q - unsigned long long</td>
# </tr>
# </table>

# %%
# Какой размер у a?
import sys
a = (1, 2)  # len(a) == 2
a.__sizeof__()

# %%
# Немного глянем inside
import ctypes
import struct
struct.unpack(f"{3 + len(a)}L", ctypes.string_at(id(a), 40))

# %%
# Playground

# %% [markdown]
# <b> Ⅱ. Устройство контейнеров → tuple (8/9)</b>

# %%
x = ([], 1, 2)
x[0] += [1]
x

# %%
x

# %%
x = ([], 1, 2)
print(f"old ID: {id(x)}")

try:
    x[0] += [1]
except TypeError:
    print('Caught an exception!')
    
print(f"new ID: {id(x)}")    
    
x

# %%
x = ([], 1, 2)
x[0].append(1)
x

# %% [markdown]
# ### Ⅱ. Устройство контейнеров → tuple (9/9)

# %% [markdown]
# * Обновление по индексу в тупле?
# * Вставка в тупл?
# * Удаление из тупла?
# * Добавление в конец тупла?
# * Сложить два тупла? (+)
# * Прибавить тупл к туплу? (+=)
# * Взять длину от тупла?
# * Поиск в тупле?

# %% [markdown]
# ### Ⅱ. Устройство контейнеров → set (1/7)

# %%
a = set([1,2,3])
type(a), bool(a), bool(set())

# %%
a = set()
a.add(1)
a.add(2)
a.add(1)
a

# %% [markdown]
# ### Ⅱ. Устройство контейнеров → set (2/7)

# %%
a = {}
b = {5}

type(a), type(b)

# %%
a = {1, 2, 3}
b = {3, 4, 5}
a - b, b - a

# %%
a | b, a & b

# %%
2 in a, 5 not in a

# %% [markdown]
# ### Ⅱ. Устройство контейнеров → set (3/7)

# %%
a = set()
a.add(1.0)

# %%
a = set()
a.add({1, 2, 3})

# %%
a = set()
a.add([1, 2])

# %%
a = set()
a.add((1, 2))

# %% [markdown]
# ### Ⅱ. Устройство контейнеров → set (4/7)

# %%
a = 1; b = 2; my_set = {1, 2}

printy("a", a)
printy("b", b)
printy("my_set", my_set)

# %% [markdown]
# ### Ⅱ. Устройство контейнеров → set (5/7)

# %%
a = {1}
b = a
b = b | {1, 4}

a, b, id(a) == id(b)

# %%
a = {1}
b = a
b |= {1, 4}

a, b, id(a) == id(b)

# %% [markdown]
# <b>Ⅱ. Устройство контейнеров → set (6/7)</b>
# <table>
# <tr>
# <td> Счетчик ссылок </td> <td>8 байт</td> <td> Q - unsigned long long</td>
# <tr/>
# <tr>
# <td> Ссылка на тип </td> <td>8 байт</td> <td> Q - unsigned long long</td>
# </tr>
# <tr>
# <td> Длина set </td> <td>8 байт</td> <td> Q - unsigned long long</td>
# </tr>
# <tr>
# <td> Число заполненных ячеек в hash-таблице </td> <td> 8 байт</td> <td> Q - unsigned long long</td>
# </tr>
# <tr>
# <td> Число существующих ячеек в hash-таблице - 1</td> <td> 8 байт</td> <td> Q - unsigned long long</td>
# </tr>
# <tr>
# <td> Ссылка на таблицу </td> <td> 8 байт</td> <td> Q - unsigned long long</td>
# </tr>
# <tr>
# <td> Хеш </td> <td> 8 байт</td> <td> q - signed long long</td>
# </tr>
# <tr>
# <td> Служебная инфо </td> <td> 8 байт</td> <td> Q - unsigned long long</td>
# </tr>
# <tr>
# <td> Вхардкоженая маленькая таблица </td> <td> 16 байт * 8</td> <td> Qq - unsigned long long + signed long long</td>
# </tr>
# <tr>
# <td> Weakref </td> <td> 8 байт</td> <td> Q - unsigned long </td>
# </tr>
# </table>

# %%
import sys

a = {5, 10, "a"}  # *range(20)
a.__sizeof__()

# %%
# Немного глянем inside
import ctypes
import struct
data_1 = struct.unpack("6QqQ" + 8*"Qq" + "Q", ctypes.string_at(id(a), 200))
print(data_1[:8]); print(data_1[8:24]); print(data_1[24:])  # id -> hash

# %%
table_id, table_size = data_1[5], data_1[4] + 1
data_2 = struct.unpack("Qq" * table_size, ctypes.string_at(table_id, 16 * table_size))
data_2

# %%
# Playground

# %% [markdown]
# ### Ⅱ. Устройство контейнеров → set (7/7)

# %% [markdown]
# * Вставка в set?
# * Поиск в set?
# * Удаление из set?
# * Длина от set?

# %% [markdown]
# ### Ⅱ. Устройство контейнеров → frozenset (1/4)

# %%
a = frozenset([1, 2, 3])
type(a), bool(a), bool(frozenset())

# %% [markdown]
# ### Ⅱ. Устройство контейнеров → frozenset (2/4)

# %%
a = frozenset([1, 2, 3])
b = frozenset([3, 4, 5])
a - b, b - a

# %%
a | b, a & b

# %%
2 in a, 5 not in a

# %% [markdown]
# ### Ⅱ. Устройство контейнеров → frozenset (3/4)

# %%
a = frozenset([1,2,3])
a.add(4)

# %%
a = frozenset([1])
b = a
b |= a

a == b, id(a) == id(b)

# %% [markdown]
# ### Ⅱ. Устройство контейнеров → frozenset (4/4)

# %%
# Такой же как set
set().__sizeof__(), frozenset().__sizeof__()

# %% [markdown]
# ### Ⅱ. Устройство контейнеров → dict (1/7)

# %%
{"a": 1, "b": 2, "c": 3}

# %%
dict(a=1, b=2, c=3)

# %%
bool({"a": 1}), bool({})

# %% [markdown]
# ### Ⅱ. Устройство контейнеров → dict (2/7)

# %%
d = {"a": 2}
d["a"]

# %%
d["b"]

# %%
d.get("b"), d.get("b", 0)

# %% [markdown]
# ### Ⅱ. Устройство контейнеров → dict (3/7)

# %%
d = {"a": 1, "b": 2}
d["b"] = 3
d["e"] = 4
d

# %%
d = {"a": 1}
d.update({"a": 3, "b": 2})
d

# %% [markdown]
# ### Ⅱ. Устройство контейнеров → dict (4/7)

# %%
d = {"a": 1, "b": 2}

for k in d:  # d.keys()
    print("Кeys:", k)
    
for v in d.values():
    print("  Values:", v)
    
for k, v in d.items():
    print("    Pairs:", k, v)

# %%
d = {"a": 1, "b": 2}
for k in d:
    del d[k]   
d

# %% [markdown]
# ### Ⅱ. Устройство контейнеров → dict (5/7)

# %%
d = {{1,2}: 3}

# %%
d = {(1,2): 3}

# %%
d = {[1,2]: 3}

# %%
d = {frozenset([1,2]): 3}

# %%
a = []

for i in range(30):
    print(a.__sizeof__())
    a.append(i)

# %% [markdown]
# ### Ⅱ. Устройство контейнеров → dict (6/7)

# %%
a = {"a": 1}
b = a
b.update({"b": 2})

a, b, id(a) == id(b)

# %% [markdown]
# ### Ⅱ. Устройство контейнеров → dict (7/7)

# %%
d = {"a": 1, "b": 2, "c": 4, "d":5}
print(d.__sizeof__())
d.clear(); print(d.__sizeof__())

# %%
{'a': 1, 'b': 2, 'c': 3}

# Pre-Python3.5:
    
#     entries = [['--', '--', '--'],
#                [-6135892715065594967, 'c', 3],
#                ['--', '--', '--'],
#                ['--', '--', '--'],
#                ['--', '--', '--'],
#                [-6219114009547292522, 'a', 1],
#                ['--', '--', '--'],
#                [6125113541592580481, 'b', 2]]

# Оптимальнее и упорядоченнее относительно вставки:

#     indices =  [None, 2, None, None, None, 0, None, 1]
#     entries =  [[-6219114009547292522, 'a', 1],
#                 [6125113541592580481, 'b', 2],
#                 [-6135892715065594967, 'c', 3]]

# %% [markdown]
# ### Ⅱ. Shallow/deep copy (1/2)

# %%
a = [1, 2, 3]
b = a.copy()
b[0] = 4

a, b

# %%
from copy import copy
a = [1, 2, 3]
b = copy(a)
b[0] = 4

a, b

# %% [markdown]
# ### Ⅱ. Shallow/deep copy (2/2)

# %%
from copy import copy
a = [1, 2, []]
b = copy(a)
b[2].append(3)
a, b

# %%
from copy import deepcopy
a = [1, 500, []]
b = deepcopy(a)
b[2].append(3)
a, b

# %% [markdown]
# ### Ⅱ. Packing/Unpacking (1/2)

# %%
a, b = 0, 1
a, b

# %%
# Как одно присвоение не перетирает другое?
a, b = b, a
a, b

# %% [markdown]
# ### Ⅱ. Packing/Unpacking (2/2)

# %%
x = [1, 2, 3, 4]

# a, b = x[0], x[1:]  # Equivalent
a, *b = x
a, b

# %%
x = [1, 2, 3, 4]

# a, b, c = x[0], x[0:-1], x[-1]  # Equivalent
a, *b, c = x
a, b, c

# %% [markdown]
# ### Ⅲ. Comprehensions  →  list comprehension

# %%
lst = []
for i in range(5):
    lst.append(i**2)
lst

# %%
lst = [i ** 2 for i in range(5)]
lst

# %% [markdown]
# ### Ⅲ. Comprehensions  → dict comprehension

# %%
dct = {}
for i in range(5):
    dct[i] = i**2
dct

# %%
dct = {i : i**2 for i in range(5)}
dct

# %% [markdown]
# ### Ⅲ. Comprehensions  → set comprehension

# %%
st = set()

for i in range(10):
    st.add(i)

st

# %%
st = {i for i in range(10)}
st

# %% [markdown]
# ### Ⅲ. Comprehensions  → comprehension with condition

# %%
lst = [i ** 2 for i in range(5)]  # len is always 5
lst

# %%
lst = [i ** 2 for i in range(5) if i % 2 == 1]  # len <= 5
lst

# %%
lst = [i ** 2 if i > 2 else i for i in range(5)]  # len is always 5
lst

# %% [markdown]
# ### Ⅲ. Collections  → defaultdict (1/3)

# %%
from collections import defaultdict
dct = defaultdict(float)

dct[2]

# %%
from collections import defaultdict
dct = defaultdict(list)

dct[2]

# %%
from collections import defaultdict
dct = defaultdict(lambda: len(dct))

dct[0], dct[1], dct[10]

# %%
float(), list()

# %% [markdown]
# ### Ⅲ. Collections  → defaultdict (2/3)

# %%
dct = {}

for i in range(100):
    j = i % 10
    if j not in dct:
        dct[j] = []
    dct[j].append(i)

dct

# %%
from collections import defaultdict

dct = defaultdict(list)

for i in range(100):
    dct[i % 10].append(i)

dict(dct)

# %% [markdown]
# ### Ⅲ. Collections  → defaultdict (3/3)

# %%
# Не делайте проверки в условиях через взятие по индексу!

dct = defaultdict(float)  # empty

for i in range(5):
    if dct[i] == 0:
        print("Found")

dct

# %% [markdown]
# ### Ⅲ. Collections  → deque (1/3)

# %%
from collections import deque
deque([1,2,3])

# %%
q = deque([1,2,3])
q.appendleft(0)
q.append(4)
q

# %%
q = deque([1,2,3])
q.popleft()
q.pop()
q

# %% [markdown]
# ### Ⅲ. Collections  → deque (2/3)

# %%
q = deque(range(100500))
# %timeit [q[i] for i in range(100500)]

# %%
q = list(range(100500))
# %timeit [q[i] for i in range(100500)]

# %%
def f():
    q = deque()
    for i in range(100500):
        q.appendleft(0)
    return q
# %timeit f()

# %%
def f():
    q = list()
    for i in range(100500):
        q.insert(0, i)
    return q
# %timeit f()

# %% [markdown]
# ### Ⅲ. Collections → deque (3/3)

# %% [markdown]
# * Вставка в начало/конец/середину?
# * Извлечение по индексу в начале/конце/середине?
# * Поиск?

# %% [markdown]
# ### Ⅲ. Collections → OrderedDict (1/3)

# %%
from collections import OrderedDict

data = OrderedDict([(1, 'a'), (3, 'c'), (2, 'b')])
data

# %%
data[1]

# %%
data.update({3: 'd', 4: 'e'})
data

# %% [markdown]
# ### Ⅲ. Collections → OrderedDict (2/3)

# %%
a = {}; a[1] = 2; a[3] = 4
b = {}; b[3] = 4; b[1] = 2
a == b

# %%
from collections import OrderedDict

a = OrderedDict(); a[1] = 2; a[3] = 4
b = OrderedDict();  b[3] = 4; b[1] = 2
a == b

# %% [markdown]
# ### Ⅲ. Collections → OrderedDict (3/3)

# %%
d = OrderedDict([(1, 'a'), (3, 'c'), (2, 'b')])
print(d)
d.move_to_end(3, last=False)
print(d)
d.popitem(last=True)
print(d)

# %% [markdown]
# ###  Ⅲ. Collections → Counter (1/2)

# %%
dct = {}
for a in "aaabbbbccd":
    if a not in dct:
        dct[a] = 0
    dct[a] += 1
dct

# %%
from collections import Counter

Counter("aaabbbbccd")

# %% [markdown]
# ###  Ⅲ. Collections → Counter (2/2)

# %%
d1 = {'a': 3, 'b': 4, 'c': 2, 'd': 1}
d2 = {'a': 4, 'b': 1}
d3 = {}

for k in d1:
    if k in d2:
        if (value := d1[k] - d2[k]) > 0:
            d3[k] = value
    else:
        d3[k] = d1[k]

d3

# %%
from collections import Counter

a = Counter("aaaaabbbbccd")
b = Counter("aaaab")
c = a - b

# %% [markdown]
# ###  Ⅲ. heapq (1/4)

# %%
import heapq

a = []
print(a)
heapq.heappush(a, 1)
print(a)
heapq.heappush(a, 2)
print(a)
heapq.heappush(a, 0)
print(a)
heapq.heappush(a, 4)
print(a)
heapq.heappush(a, -1)
print(a)

# %%
while a:
    value = heapq.heappop(a)
    print(value, a)

# %% [markdown]
# ###  Ⅲ. heapq (2/4)

# %%
# Получить 3 максимальных элемента с ограничением размера кучи

a = []
for value in [1, 5, 7, 2, 4, 3]:
    print(a)
    if len(a) != 3:
        heapq.heappush(a, value)
    elif a[0] < value:
        heapq.heapreplace(a, value)
a

# %%
# Получить 3 максимальных элемента

a = [1, 5, 7, 2, 4, 3]
heapq.nlargest(3, a)

# %% [markdown]
# ###  Ⅲ. heapq (3/4)

# %%
import random
t = [random.randint(0, 100) for i in range(1005000)]

def f(n, k):
    return heapq.nlargest(k, n)

# %timeit f(t, 3)

# %%
import random
t = [random.randint(0, 100) for i in range(1005000)]

def f(n, k):
    maxs = sorted(n, reverse=True)[:k]
    
# %timeit f(t, 3)

# %% [markdown]
# ###  Ⅲ. heapq (4/4)

# %% [markdown]
# * Найти минимум/максимум списка?
# * Найти k максимальных элементов в списке

# %% [markdown]
# # Python is not memory safe

# %%
import ctypes
x = "hello world"
ctypes.pythonapi.PyObject_Free(x)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
